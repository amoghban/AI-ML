# %%
import pandas as pd

df = pd.read_csv("Automobile_data.csv")

# Get the count of null values for every column
null_counts = df.isna().sum()

print (null_counts.to_dict())

filtered_dict = {key: value for key, value in null_counts.to_dict().items() if value != 0}

print(filtered_dict)

print(filtered_dict.keys())

rows_with_nulls = df[df[filtered_dict.keys()].isna().any(axis=1)]

rows_with_nulls

df.drop_duplicates
# Out:
# {'index': 0, 'company': 0, 'body-style': 0, 'wheel-base': 0, 'length': 0, 'engine-type': 0, 'num-of-cylinders': 0, 'horsepower': 0, 'average-mileage': 0, 'price': 3}
# {'price': 3}
# dict_keys(['price'])
# <bound method DataFrame.drop_duplicates of     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# ...
